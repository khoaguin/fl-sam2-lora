# %% [markdown]
# # Data Scientist (DS) - Federated SAM2LoRA Medical Image Segmentation
#
# This notebook is for **Data Scientists** who want to train a federated SAM2 model with LoRA adapters for medical image segmentation across multiple hospitals/data owners.
#
# ## Architecture Overview
# - **4 Data Owners (DOs)** with different capabilities:
#   - **DO 1 (Zero-shot)**: No labeled data - uses CLIP text prompts only
#   - **DO 2 (Few-shot)**: 1-5 labeled images - uses memory bank
#   - **DO 3 (LoRA)**: >10 labeled images - full LoRA training
#   - **DO 4 (LoRA)**: >10 labeled images - full LoRA training
# - **Aggregation**: FedAvg on LoRA weights (only DO 3 & 4 contribute)
# - **Model**: SAM2 with LoRA adapters (~2-8 MB transferred)
#
# ## What this notebook does:
# 1. **Login** as a Data Scientist using your Google account
# 2. **Add peers** (Data Owners/hospitals) to collaborate with
# 3. **Explore datasets** available at each Data Owner site
# 4. **Submit** FL training jobs to Data Owners
# 5. **Coordinate** federated learning and aggregate LoRA adapters
# 6. **Save** the final aggregated model
#
# ## Prerequisites
# 1. Go to https://colab.research.google.com/
# 2. Upload this notebook with `File` -> `Upload Notebook`

# %% [markdown]
# ## Install Dependencies

# %%
# Install syft-flwr from the development branch
# !uv pip install -v "git+https://github.com/OpenMined/syft-flwr.git@feat/syft-client-p2p" 2>&1 | grep -E "(OpenMined/syft-flwr|OpenMined/syft-client).*[0-9a-f]{7}"

# %% [markdown]
# ## Login as Data Scientist
#
# Login using your Google account. This will:
# - Authenticate with Google Drive
# - Create your SyftBox folder structure
# - Enable P2P communication with Data Owners

# %%
import syft_client as sc
import syft_flwr

print(f"{sc.__version__ = }")
print(f"{syft_flwr.__version__ = }")

# ds_email = input("Enter the Data Scientist's email: ")
ds_email = "your.ds.email@gmail.com"  # Replace with your email
ds_client = sc.login_ds(email=ds_email)

# %% [markdown]
# ## Add Peer Data Owners
#
# Add the Data Owners (hospitals) you want to collaborate with.
# They must also add you as a peer from their side.
#
# For SAM2LoRA FL, we have 4 DOs:
# - DO 1: Zero-shot client (no data)
# - DO 2: Few-shot client (1-5 samples)
# - DO 3: LoRA training client (>10 samples)
# - DO 4: LoRA training client (>10 samples)

# %%
# Add Data Owners - Replace with actual emails
do1_email = "do1.zeroshot@gmail.com"  # DO 1 - Zero-shot
do2_email = "do2.fewshot@gmail.com"   # DO 2 - Few-shot
do3_email = "do3.lora@gmail.com"      # DO 3 - LoRA
do4_email = "do4.lora@gmail.com"      # DO 4 - LoRA

# Add all peers
ds_client.add_peer(do1_email)
ds_client.add_peer(do2_email)
ds_client.add_peer(do3_email)
ds_client.add_peer(do4_email)

print(f"\nCurrent peers:")
ds_client.peers

# %% [markdown]
# ## Explore Datasets
#
# View available medical imaging datasets at each Data Owner site.
# You can only see metadata and mock (anonymized) samples, not the actual private data.

# %%
# View datasets from DO1 (Zero-shot - may have no data)
do1_datasets = ds_client.datasets.get_all(datasite=do1_email)
print(f"DO1 datasets: {len(do1_datasets)}")
do1_datasets

# %%
# View datasets from DO2 (Few-shot)
do2_datasets = ds_client.datasets.get_all(datasite=do2_email)
print(f"DO2 datasets: {len(do2_datasets)}")
if len(do2_datasets) > 0:
    do2_datasets[0].describe()

# %%
# View datasets from DO3 (LoRA)
do3_datasets = ds_client.datasets.get_all(datasite=do3_email)
print(f"DO3 datasets: {len(do3_datasets)}")
if len(do3_datasets) > 0:
    do3_datasets[0].describe()

# %%
# View datasets from DO4 (LoRA)
do4_datasets = ds_client.datasets.get_all(datasite=do4_email)
print(f"DO4 datasets: {len(do4_datasets)}")
if len(do4_datasets) > 0:
    do4_datasets[0].describe()

# %%
# Collect mock dataset URLs for simulation
mock_dataset_urls = []
for datasets in [do1_datasets, do2_datasets, do3_datasets, do4_datasets]:
    if datasets:
        mock_dataset_urls.append(datasets[0].mock_url)
print(f"Mock dataset URLs: {mock_dataset_urls}")

# %% [markdown]
# ## Setup FL Project
#
# Clone or setup the FL project for SAM2LoRA segmentation.

# %%
from pathlib import Path

# Clone the FL project from GitHub
# !mkdir -p /content/fl-sam2-lora
# !curl -sL https://github.com/OpenMined/fl-sam2-lora/archive/refs/heads/main.tar.gz | tar -xz --strip-components=1 -C /content/fl-sam2-lora

SYFT_FLWR_PROJECT_PATH = Path("/content/fl-sam2-lora")

print(f"syft-flwr project at: {SYFT_FLWR_PROJECT_PATH}")

# %% [markdown]
# ## Bootstrap FL Project
#
# Configure the FL project with the aggregator (you) and datasites (Data Owners).

# %%
import syft_flwr

try:
    # Clean up old main.py if exists
    main_py = SYFT_FLWR_PROJECT_PATH / "main.py"
    if main_py.exists():
        main_py.unlink()

    print(f"syft_flwr version = {syft_flwr.__version__}")

    # Get all peer emails
    do_emails = [peer.email for peer in ds_client.peers]
    print(f"Data Owners: {do_emails}")
    print(f"Aggregator: {ds_email}")

    # Bootstrap the project
    syft_flwr.bootstrap(
        SYFT_FLWR_PROJECT_PATH,
        aggregator=ds_email,
        datasites=do_emails
    )
    print("Bootstrapped project successfully")
except Exception as e:
    print(f"Error: {e}")

# %% [markdown]
# ## Run Local Simulation (Optional)
#
# Test the FL pipeline locally with mock data before submitting to real Data Owners.

# %%
RUN_SIMULATION = False  # Set to True to run simulation

if RUN_SIMULATION:
    # Clean pycache
    import shutil
    pycache = SYFT_FLWR_PROJECT_PATH / "fl_sam2_segmentation" / "__pycache__"
    if pycache.exists():
        shutil.rmtree(pycache)

    print(f"Running simulation with mock paths: {mock_dataset_urls}")
    syft_flwr.run(SYFT_FLWR_PROJECT_PATH, mock_dataset_urls)

# %% [markdown]
# ## Submit FL Job to Data Owners
#
# Submit the FL training job to each Data Owner.
# They will need to approve and run the job on their local data.

# %%
# Clean pycache before submitting
import shutil
pycache = SYFT_FLWR_PROJECT_PATH / "fl_sam2_segmentation" / "__pycache__"
if pycache.exists():
    shutil.rmtree(pycache)

job_name = "fl-sam2-lora-training"

# Submit to DO1 (Zero-shot)
ds_client.submit_python_job(
    user=do1_email,
    code_path=str(SYFT_FLWR_PROJECT_PATH),
    job_name=job_name,
)
print(f"Job submitted to {do1_email} (Zero-shot)")

# %%
# Submit to DO2 (Few-shot)
ds_client.submit_python_job(
    user=do2_email,
    code_path=str(SYFT_FLWR_PROJECT_PATH),
    job_name=job_name,
)
print(f"Job submitted to {do2_email} (Few-shot)")

# %%
# Submit to DO3 (LoRA)
ds_client.submit_python_job(
    user=do3_email,
    code_path=str(SYFT_FLWR_PROJECT_PATH),
    job_name=job_name,
)
print(f"Job submitted to {do3_email} (LoRA)")

# %%
# Submit to DO4 (LoRA)
ds_client.submit_python_job(
    user=do4_email,
    code_path=str(SYFT_FLWR_PROJECT_PATH),
    job_name=job_name,
)
print(f"Job submitted to {do4_email} (LoRA)")

# %%
# Check submitted jobs
ds_client.jobs

# %% [markdown]
# ## Run FL Server (Aggregator)
#
# Run the FL server to:
# 1. Wait for Data Owners to complete their local training
# 2. Aggregate LoRA adapter weights using FedAvg (only DO3 & DO4 contribute)
# 3. Coordinate multiple training rounds
# 4. Save the final aggregated model

# %%
# Install additional dependencies for SAM2
# !uv pip install \
    "torch>=2.0.0" \
    "torchvision>=0.15.0" \
    "peft>=0.5.0" \
    "opencv-python>=4.8.0" \
    "Pillow>=10.0.0" \
    "numpy>=1.24.0" \
    "scipy>=1.10.0" \
    "scikit-learn>=1.3.0" \
    "pandas>=2.0.0" \
    "loguru>=0.7.0" \
    "tqdm>=4.65.0" \
    "transformers>=4.30.0" \
    "open_clip_torch>=2.20.0"

# %%
# Run the FL server (aggregator)
assert SYFT_FLWR_PROJECT_PATH.exists(), f"Project path does not exist: {SYFT_FLWR_PROJECT_PATH}"
assert (SYFT_FLWR_PROJECT_PATH / "main.py").exists(), f"main.py not found"

syftbox_folder = f"/content/SyftBox_{ds_email}"

# !SYFTBOX_EMAIL="{ds_email}" SYFTBOX_FOLDER="{syftbox_folder}" \
    uv run {str(SYFT_FLWR_PROJECT_PATH / "main.py")}

# %% [markdown]
# ## View Results
#
# After training completes, view the aggregated model and metrics.

# %%
# Check for saved model weights
import os

output_dir = SYFT_FLWR_PROJECT_PATH / "outputs"

if output_dir.exists():
    print(f"Output directory: {output_dir}")
    print(f"Files:")
    for f in output_dir.iterdir():
        print(f"  - {f.name}")
else:
    print("No output directory found yet. Training may still be in progress.")

# %%
# Load FL history
import json

history_path = output_dir / "fl_history.json"
if history_path.exists():
    with open(history_path) as f:
        fl_history = json.load(f)
    
    print("FL Training History:")
    print(f"  Rounds: {fl_history['config']['num_rounds']}")
    print(f"  Local Epochs: {fl_history['config']['local_epochs']}")
    print(f"  Learning Rate: {fl_history['config']['learning_rate']}")
    print(f"  LoRA Rank: {fl_history['config']['lora_rank']}")
    print(f"\nGlobal Dice Scores: {fl_history['global_dice']}")
    print(f"Final Dice: {fl_history['global_dice'][-1]:.4f}")
else:
    print("No FL history found yet.")

# %%
# Plot training progress
import matplotlib.pyplot as plt

if 'fl_history' in dir():
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    rounds = range(1, len(fl_history['global_dice']) + 1)
    
    axes[0].plot(rounds, fl_history['global_loss'], 'b-o')
    axes[0].set_xlabel('Round')
    axes[0].set_ylabel('Loss')
    axes[0].set_title('Global Model Loss')
    axes[0].grid(True, alpha=0.3)
    
    axes[1].plot(rounds, fl_history['global_dice'], 'g-o')
    axes[1].set_xlabel('Round')
    axes[1].set_ylabel('Dice Score')
    axes[1].set_title('Global Model Dice Score')
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Clean Up
#
# Optional: Delete the SyftBox folder from your Drive when done.

# %%
# WARNING: This will delete your SyftBox folder!
# Uncomment to run:
# ds_client.delete_syftbox()

# %% [markdown]
# ## Debug (Optional)
#
# View your SyftBox folder structure for debugging.

# %%
from google.colab import drive

drive.mount('/content/drive')

# !sudo apt install tree -qq

# !tree ./drive/MyDrive/SyftBox
