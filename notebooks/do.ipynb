# %% [markdown]
# # Data Owner (DO) - Federated SAM2LoRA Medical Image Segmentation
#
# This notebook is for **Data Owners** (hospitals/medical institutions) participating in federated learning for medical image segmentation.
#
# ## Client Types
# Depending on your data availability, you will operate as one of:
# - **DO 1 (Zero-shot)**: No labeled data - uses CLIP text prompts only
# - **DO 2 (Few-shot)**: 1-5 labeled images - uses memory bank
# - **DO 3 (LoRA)**: >10 labeled images - full LoRA training
# - **DO 4 (LoRA)**: >10 labeled images - full LoRA training
#
# ## What this notebook does:
# 1. **Login** to your datasite using your Google account
# 2. **Upload** your medical imaging dataset (images + masks)
# 3. **View** submitted FL jobs from Data Scientists
# 4. **Approve** and **run** FL training jobs
# 5. Your data **never leaves** your system - only model updates (LoRA adapters ~2-8 MB) are shared
#
# ## Prerequisites
# 1. Go to https://colab.research.google.com/
# 2. Upload this notebook with `File` -> `Upload Notebook`

# %% [markdown]
# ## Install Dependencies

# %%
# Install syft-flwr from the development branch
# !uv pip install -v "git+https://github.com/OpenMined/syft-flwr.git@feat/main"

# %% [markdown]
# ## Login to Datasite
#
# Login as a Data Owner using your Google account. This will:
# - Authenticate with Google Drive
# - Create your SyftBox folder structure
# - Enable P2P communication with Data Scientists

# %%
import syft_client as sc
import syft_flwr

print(f"{sc.__version__ = }")
print(f"{syft_flwr.__version__ = }")

# do_email = input("Enter the Data Owner's email: ")
do_email = "your.do1.email@gmail.com"  # Replace with your email
do_client = sc.login_do(email=do_email)

# %% [markdown]
# ## View Peers
#
# Check which Data Scientists have connected to your datasite.

# %%
# View connected Data Scientists
do_client.peers

# %% [markdown]
# ## Upload Medical Imaging Dataset
#
# **IMPORTANT**: Please add this DO as peer on the DS side before uploading the dataset.
# If not, the DS will not be able to discover the dataset.
#
# ### Dataset Structure for Chest CT Segmentation
# Your dataset should have the following structure:
# ```
# dataset/
# ├── images/
# │   └── images/
# │       ├── patient001_slice001.jpg
# │       ├── patient001_slice002.jpg
# │       └── ...
# ├── masks/
# │   └── masks/
# │       ├── patient001_mask_slice001.jpg
# │       ├── patient001_mask_slice002.jpg
# │       └── ...
# ├── train.csv  (columns: ImageId, MaskId)
# ├── mock/
# │   ├── images/  (synthetic/anonymized samples for preview)
# │   └── masks/
# └── README.md
# ```
#
# ### Sample Counts by Client Type
# - **DO 1 (Zero-shot)**: 0 samples (no data upload needed)
# - **DO 2 (Few-shot)**: 4 train + 2 test samples
# - **DO 3 (LoRA)**: 16 train + 4 test samples
# - **DO 4 (LoRA)**: 14 train + 4 test samples

# %%
from pathlib import Path
from huggingface_hub import snapshot_download

# Download the Chest CT Segmentation dataset
DATASET_DIR = Path("./dataset/").expanduser().absolute()

if not DATASET_DIR.exists():
    print("Downloading Chest CT Segmentation dataset...")
    snapshot_download(
        repo_id="khoaguin/chest-ct-segmentation",  # Replace with actual HF dataset
        repo_type="dataset",
        local_dir=DATASET_DIR,
    )
    print(f"Dataset downloaded to: {DATASET_DIR}")
else:
    print(f"Dataset already exists at: {DATASET_DIR}")

DATASET_PATH = DATASET_DIR / "chest-ct-segmentation"
print(f"Dataset path: {DATASET_PATH}")

# %%
# Configure your client type
# Options: "DO_1_zeroshot", "DO_2_fewshot", "DO_3_lora", "DO_4_lora"
CLIENT_TYPE = "DO_1_zeroshot"  # Change this based on your role

# Sample configuration by client type
SAMPLE_CONFIG = {
    "DO_1_zeroshot": {"train": 0, "test": 0, "description": "Zero-shot (CLIP text prompts only)"},
    "DO_2_fewshot": {"train": 4, "test": 2, "description": "Few-shot (memory bank)"},
    "DO_3_lora": {"train": 16, "test": 4, "description": "LoRA training"},
    "DO_4_lora": {"train": 14, "test": 4, "description": "LoRA training"},
}

config = SAMPLE_CONFIG[CLIENT_TYPE]
print(f"Client Type: {CLIENT_TYPE}")
print(f"Description: {config['description']}")
print(f"Training samples: {config['train']}")
print(f"Test samples: {config['test']}")

# %%
# Create and upload the dataset (skip for zero-shot)
if config["train"] > 0:
    do_client.create_dataset(
        name="chest-ct-segmentation",
        mock_path=DATASET_PATH / "mock" if (DATASET_PATH / "mock").exists() else DATASET_PATH,
        private_path=DATASET_PATH,
        summary=f"Chest CT Segmentation dataset for {CLIENT_TYPE} ({config['description']})",
        readme_path=DATASET_PATH / "README.md" if (DATASET_PATH / "README.md").exists() else None,
        tags=["medical", "segmentation", "sam2", "ct", CLIENT_TYPE],
        sync=True,
    )
    print(f"Dataset uploaded for {CLIENT_TYPE}")
else:
    print(f"Zero-shot client ({CLIENT_TYPE}) - no dataset upload needed")

# %%
# View all datasets
do_client.datasets.get_all()

# %% [markdown]
# ## View Submitted Jobs
#
# Check for FL training jobs submitted by Data Scientists.

# %%
# List all submitted jobs
do_client.jobs

# %%
# View details of a specific job
if len(do_client.jobs) > 0:
    print(do_client.jobs[0])

# %% [markdown]
# ## Approve Submitted Jobs
#
# Review and approve FL training jobs. This allows the job to run on your data.
#
# **Important**: Review the job code before approving to ensure it:
# - Only trains LoRA adapters (not the full model)
# - Does not export raw data
# - Follows your data governance policies

# %%
# Approve the first pending job
if len(do_client.jobs) > 0:
    do_client.jobs[0].approve()
    print("Job approved!")
else:
    print("No jobs to approve")

# %% [markdown]
# ## Run Approved Jobs
#
# Execute the approved FL training job. Depending on your client type, this will:
#
# - **Zero-shot (DO 1)**: Use CLIP text prompts for segmentation (no training)
# - **Few-shot (DO 2)**: Build memory bank from examples (no gradient training)
# - **LoRA (DO 3 & 4)**: Train SAM2 LoRA adapters on your data
#
# **Only LoRA clients (DO 3 & 4) contribute weights to aggregation!**
#
# **Your raw data never leaves your system!**

# %%
# Process approved jobs
do_client.process_approved_jobs()

# %% [markdown]
# ## Check Job Status

# %%
# Check status of all jobs
do_client.jobs

# %% [markdown]
# ## Clean Up
#
# Optional: Delete the SyftBox folder from your Drive when done.

# %%
# WARNING: This will delete your SyftBox folder!
# Uncomment to run:
# do_client.delete_syftbox()

# %% [markdown]
# ## Debug (Optional)
#
# View your SyftBox folder structure for debugging.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !sudo apt install tree -qq
# !tree ./drive/MyDrive/SyftBox

# %%
# Debug: View shared folders (for troubleshooting P2P connections)
from google.colab import auth
from googleapiclient.discovery import build

auth.authenticate_user()
drive_service = build('drive', 'v3')

def list_shared_folder_tree(folder_name=None, owner_email=None, indent=0):
    """List contents of a shared folder recursively"""
    query_parts = ["sharedWithMe=true", "trashed=false"]
    if folder_name:
        query_parts.append(f"name='{folder_name}'")
    if owner_email:
        query_parts.append(f"'{owner_email}' in owners")

    query = " and ".join(query_parts)

    results = drive_service.files().list(
        q=query,
        fields="files(id, name, mimeType, owners)"
    ).execute()

    for f in results.get('files', []):
        prefix = "  " * indent
        owner = f.get('owners', [{}])[0].get('emailAddress', 'unknown')
        is_folder = f['mimeType'] == 'application/vnd.google-apps.folder'
        print(f"{prefix}{'[DIR]' if is_folder else '[FILE]'} {f['name']} (owner: {owner})")

        if is_folder:
            list_folder_contents(f['id'], indent + 1)

def list_folder_contents(folder_id, indent=0):
    """List contents of a folder by ID"""
    results = drive_service.files().list(
        q=f"'{folder_id}' in parents and trashed=false",
        fields="files(id, name, mimeType)"
    ).execute()

    for f in results.get('files', []):
        prefix = "  " * indent
        is_folder = f['mimeType'] == 'application/vnd.google-apps.folder'
        print(f"{prefix}{'[DIR]' if is_folder else '[FILE]'} {f['name']}")

        if is_folder:
            list_folder_contents(f['id'], indent + 1)

print("=== Shared SyftBox folders ===")
list_shared_folder_tree(folder_name="SyftBox")
